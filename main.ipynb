# %%
import time
from evolutionary_algorithm.umdac import UMDAc
from evolutionary_algorithm.pbilc import PBILc
from evolutionary_algorithm.pbil import PBIL
from evolutionary_algorithm.de import DE
from evolutionary_algorithm.base_functions.objective import Objective
from evolutionary_algorithm.base_functions.selection import Selection
from move_strategies.strategies import MoveStrategy

# %%
start_time = time.time()
pbil_random = PBIL(objective=Objective(),population_size=50, descendant_size=20, opponent_strategy=MoveStrategy.minimax, iters=30, n=2, learning_rate=0.1, mutation_probability=0.05, mutation_constant=0.15, depth=2)
pbil_random.run_n_times()
pbil_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [-7 -2 -2 -1 10] [ 1  6 -4 -1  6] [3]
# n: 0, iter: 1
# [ 7  1 -1 -3 -3] [-9 -5 -4  4  0] [8]
# n: 0, iter: 2
# [  4 -10  -1   0  -7] [-5  5  0 -2 -7] [-10]
# n: 0, iter: 3
# [-7  2  9 -4 -2] [-2 -9 -1  8  8] [1]
# n: 0, iter: 4
# [-7 -7  9  6 -3] [-1 -5 -4 -6  8] [-4]
# n: 0, iter: 5
# [ -4 -10   1  -9  -7] [-8 -5 -4  4 -9] [-1]
# n: 0, iter: 6
# [-9 -7 -9  6 -3] [-2  1  9  8  2] [8]
# n: 0, iter: 7
# [ -7   9   9  -1 -10] [-2 -9  9  8 -7] [9]
# n: 0, iter: 8
# [ -7 -10  -1  -2   4] [-2 -1 -4  8 -7] [-6]
# n: 0, iter: 9
# [-5  8 -7 -9 -9] [-1 -9  9  9  4] [3]
# n: 0, iter: 10
# [ -7  -7 -10  -1  -3] [-8  0  6  8  5] [-1]
# n: 0, iter: 11
# [  6 -10  -8 -10  -7] [-5 -3 -4  8  5] [0]
# n: 0, iter: 12
# [ -7 -10   9   6  -9] [-8 -3 -7 -9 -7] [9]
# n: 0, iter: 13
# [  8 -10  -8  -1  -9] [ 0  0 -4  4  0] [9]
# n: 0, iter: 14
# [ -4 -10   9  -9  -2] [-1  5  9  4  5] [9]
# ...

# %%
start_time = time.time()
pbil_random = PBIL(objective=Objective(),population_size=50, descendant_size=20, opponent_strategy=MoveStrategy.minimax, iters=30, n=2, learning_rate=0.22, mutation_probability=0.1, mutation_constant=0.15, depth=2)
pbil_random.run_n_times()
pbil_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [ -9   6 -10   1   8] [ 1  8 -8 -3 -1] [0]
# n: 0, iter: 1
# [-4 -8  6 -7  8] [ -5 -10  -4   9   1] [0]
# n: 0, iter: 2
# [  6   6 -10   6   3] [ 2 -7  6  9  1] [6]
# n: 0, iter: 3
# [ 6 -6 -6 -7 -7] [ 2  1  4 -1 -1] [-4]
# n: 0, iter: 4
# [-4 -8  4  6 -7] [-5  3  6  9 10] [1]
# n: 0, iter: 5
# [ 4 -8 -4 -2 -7] [ 2  8 -5 -3 10] [1]
# n: 0, iter: 6
# [-4 -8 -4 -2 -7] [ 2  8 -7 10 10] [1]
# n: 0, iter: 7
# [-4 10 -5 -5  8] [ 2  8 -7  9  7] [-4]
# n: 0, iter: 8
# [-4  6 -8 -5 -7] [ 2  3 -8  3  7] [0]
# n: 0, iter: 9
# [ 4 -8 -5  6  8] [ 2  3 -4  3  7] [0]
# n: 0, iter: 10
# [ 6  6  2 -9 -7] [2 3 6 3 7] [10]
# n: 0, iter: 11
# [ 6 -9 -8 -5 -7] [-1  0 -4  1 10] [1]
# n: 0, iter: 12
# [-4  6 -8 -5 -7] [-9  0  6  3 10] [0]
# n: 0, iter: 13
# [-4 -8 -8 -9 -7] [-9 -3 -4  6 10] [10]
# n: 0, iter: 14
# [-8 -8 -8 -5 -7] [-9  6  3  1  5] [10]
# n: 0, iter: 15
# ...

# %%
start_time = time.time()
pbil_random = PBIL(objective=Objective(),population_size=70, descendant_size=20, opponent_strategy=MoveStrategy.minimax, iters=50, n=1, learning_rate=0.22, mutation_probability=0.1, mutation_constant=0.15, depth=2)
pbil_random.run_n_times()
pbil_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [ 4 -3 10 -2 -3] [ 9 -3 -4 -5 -6] [-4]
# n: 0, iter: 1
# [ 5 -3 10 -2 -8] [ 6 -5 -4 -7  0] [-10]
# n: 0, iter: 2
# [-9 -3 -1 -7 -3] [ 8 -5 -9 -4 -6] [9]
# n: 0, iter: 3
# [ 5 -3  4 -7  1] [ 3  6 -9 -4 -8] [-4]
# n: 0, iter: 4
# [ 4 -3 -5 -7 -2] [ 6 -5 -9  0  6] [6]
# n: 0, iter: 5
# [ -9  -3  -1  -7 -10] [ 6 -5 -9 -4 -6] [6]
# n: 0, iter: 6
# [-9 -3 -9 -7  1] [ 4 -5 -8  1  0] [6]
# n: 0, iter: 7
# [  6  -3   1   2 -10] [ 6 -3 -9  1 -8] [6]
# n: 0, iter: 8
# [  6  -3  -5  -2 -10] [ 6  6 -9  2  0] [6]
# n: 0, iter: 9
# [  6  -3  -1   3 -10] [ 6  6 -9  1  8] [9]
# n: 0, iter: 10
# [ -9  -3  -1  -8 -10] [ 4 -5 -9  1  8] [8]
# n: 0, iter: 11
# [  5   3   1  -8 -10] [ 4  6 -2  2  0] [8]
# n: 0, iter: 12
# [ -9  -3  -6  -8 -10] [-7  6 -9  2  6] [8]
# n: 0, iter: 13
# [  6  -3   4  -2 -10] [-7 -5 -2  2  8] [-6]
# n: 0, iter: 14
# [-9 -3  4 -5  2] [-1  6 -2  2 -8] [8]
# n: 0, iter: 15
# ...

# %%
start_time = time.time()
pbil_random = PBIL(objective=Objective(),population_size=200, descendant_size=20, opponent_strategy=MoveStrategy.minimax, iters=50, n=1, learning_rate=0.35, mutation_probability=0.05, mutation_constant=0.3, depth=2)
pbil_random.run_n_times()
pbil_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [ 1 -5 -2  6 -3] [ 0  4 -4  0 -7] [-9]
# n: 0, iter: 1
# [-3 -5 -2  6 -8] [ 7 -9  5  7 -9] [-9]
# n: 0, iter: 2
# [ 1  1 -2  6 -5] [ 7  4  5  7 10] [1]
# n: 0, iter: 3
# [-3 -9 -2  3 -8] [ 7 -9  5 -3  5] [-9]
# n: 0, iter: 4
# [-3 -9 -2  7 -5] [-3  4 -4 -3 -5] [-9]
# n: 0, iter: 5
# [ 1 -9 -2  3 -8] [ 8 -9  5 -3 10] [-9]
# n: 0, iter: 6
# [-5 10 -4 -4 -8] [ 8  4  5 -3 10] [1]
# n: 0, iter: 7
# [ 6 10  9 -4 -8] [-3  4  5 -3 -3] [-9]
# n: 0, iter: 8
# [ 6 10  9  3 -8] [ 7  4 -4 -3 -4] [-7]
# n: 0, iter: 9
# [ 6 10  9  3 -8] [ 7 -9 -4 -3 -9] [-9]
# n: 0, iter: 10
# [ 6 10  9  3 -8] [ 7 -9  5 -3 -4] [-9]
# n: 0, iter: 11
# [ 6 10  9  3 -8] [-5 -9 -4 -3 -9] [-9]
# n: 0, iter: 12
# [ 6 10  9  3 -8] [-5 -9 -4 -3 -9] [-7]
# n: 0, iter: 13
# [ 6 10  9 -4 -8] [-7 -9 -4 -3 -9] [-9]
# n: 0, iter: 14
# [ 6 10  9  3 -8] [ 7 -9 -4 -3 -4] [-9]
# n: 0, iter: 15
# ...

# %%
start_time = time.time()
pbil_random = PBIL(objective=Objective(),population_size=200, descendant_size=20, opponent_strategy=MoveStrategy.minimax, iters=50, n=1, learning_rate=0.5, mutation_probability=0.085, mutation_constant=0.4, depth=2)
pbil_random.run_n_times()
pbil_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [-1  8  6  4  1] [ -7 -10  10  -3  -4] [-7]
# n: 0, iter: 1
# [-1  8  6  4  1] [ -7 -10  10  -3  -4] [-7]
# n: 0, iter: 2
# [-1  8  6  4  1] [ -7 -10  10  -3  -4] [-2]
# n: 0, iter: 3
# [-5  8  6 -3  1] [ -7 -10  10  -3  -4] [-2]
# n: 0, iter: 4
# [-5  8  6  4  1] [-7  0 10 -3 -4] [-2]
# n: 0, iter: 5
# [-5  8  6  4  1] [-7  0 10 -3 -4] [-2]
# n: 0, iter: 6
# [-1  8  6  4  1] [-7  0 10 -3 -4] [-2]
# n: 0, iter: 7
# [-1  8 -7  4  1] [-7  0 10 -3 -4] [-2]
# n: 0, iter: 8
# [-1  8 -7  4  1] [-7  0 10 -3 -4] [-2]
# n: 0, iter: 9
# [-1  8 -7 -3  1] [-7  4 10 -3 -4] [-2]
# n: 0, iter: 10
# [-1  8 -7 -3  1] [-7  4 10 -3 -4] [-2]
# n: 0, iter: 11
# [-1  8 -7 -3 -3] [-7  4 10  1 -4] [-2]
# n: 0, iter: 12
# [-1  8 -7 -3  5] [-7  4 10  1  4] [-2]
# n: 0, iter: 13
# [-5  8 -7 -3 -4] [-7  4 10  1 -8] [-2]
# n: 0, iter: 14
# [-5  8 -7 -3 -4] [-7  4 10  1 -8] [-2]
# n: 0, iter: 15
# ...

# %%
v
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [ -4 -10   5  -4   2] [-4 -1  1 -5 -8] [6]
# n: 0, iter: 1
# [-4 -7  5 -4  2] [-1 -1  1 -5  7] [2]
# n: 0, iter: 2
# [ -4 -10   5  -4   2] [ 7 -1  1 -5 -8] [10]
# n: 0, iter: 3
# [-4 -7 -2 -4  2] [ 7 -1 -4 -5 -8] [5]
# n: 0, iter: 4
# [ -4 -10   5  -4   2] [-1 -1 -4 -5 -8] [-9]
# n: 0, iter: 5
# [ -4 -10   5  -4   2] [-1 -1 -4 -5 -8] [2]
# n: 0, iter: 6
# [ -4 -10   5  -4   2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 7
# [-4 -7  5 -4  2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 8
# [ -4 -10   5  -4   2] [-1 -1 -4 -5 -8] [2]
# n: 0, iter: 9
# [-4 -7  5 -4  2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 10
# [ -4 -10   5  -4   2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 11
# [ -5 -10   5  -4   2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 12
# [ -5 -10   5  -4   2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 13
# [ -5 -10   5  -4   2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 14
# [ -5 -10   5  -4   2] [-1 -1 -4 -5  7] [2]
# ...

# %%
start_time = time.time()
pbil_random = PBIL(objective=Objective(),population_size=500, descendant_size=50, opponent_strategy=MoveStrategy.minimax, iters=150, n=1, learning_rate=0.65, mutation_probability=0.1, mutation_constant=0.35, depth=2)
pbil_random.run_n_times()
pbil_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
