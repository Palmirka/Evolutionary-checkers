# %%
from evolutionary_algorithm.umdac import UMDAc
from evolutionary_algorithm.pbilc import PBILc
from evolutionary_algorithm.base_functions.objective import Objective
from evolutionary_algorithm.base_functions.selection import Selection
from move_strategies.strategies import MoveStrategy

# %%
umdac_random = UMDAc(selection_function=Selection.tournament,objective_function=Objective.function, population_size=4, descendant_size=4, opponent_strategy=MoveStrategy.random, iters=10, n=2)
print(umdac_random.run_n_times())
umdac_random.show_coefficients()
umdac_random.show()
# Out:
# [[-0.08231721  0.83012068  0.34334985 -0.18664616  0.63168059  0.17335413
#    0.6819655  -0.46120322  1.52366851 -1.07719028 -0.19510725 -0.74397644]
#  [ 0.4217601  -0.33786634  0.52661583  0.94825989  0.63961833 -0.37384905
#    2.39518914  0.66050756  0.14658566 -0.4290831  -0.06017268 -0.73000542]]
