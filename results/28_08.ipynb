# %%
import time
import numpy as np
from evolutionary_algorithm.umdac import UMDAc
from evolutionary_algorithm.pbilc import PBILc
from evolutionary_algorithm.pbil import PBIL
from evolutionary_algorithm.de import DE
from evolutionary_algorithm.base_functions.objective import Objective
from evolutionary_algorithm.base_functions.selection import Selection
from move_strategies.strategies import MoveStrategy

# %%
start_time = time.time()
pbil = PBILc(objective=Objective(), population_size=500, games_for_iter=3, opponent_strategy_list= np.array([(MoveStrategy(depth=2).minimax, 50)]), n=1, learning_rate=0.55, mutation_probability=0.1, disturbance_probability=0.05, disturbance_constant=0.2)
pbil.run_n_times()
pbil.save()
pbil.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# n: 0, iter: 1
# n: 0, iter: 2
# n: 0, iter: 3
# n: 0, iter: 4
# n: 0, iter: 5
# n: 0, iter: 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 start_time = time.time()
#       2 pbil = PBILc(objective=Objective(), population_size=500, games_for_iter=3, opponent_strategy_list= np.array([(MoveStrategy(depth=2).minimax, 50)]), n=1, learning_rate=0.55, mutation_probability=0.1, disturbance_probability=0.05, disturbance_constant=0.2)
# ----> 3 pbil.run_n_times()
#       4 pbil.save()
#       5 pbil.show()
#
# File ~/Documents/xd/Evolutionary-checkers/evolutionary_algorithm/evolutionary.py:117, in Evolutionary.run_n_times(self)
#     114 """Save results from n runs of function"""
#     116 for x in range(self.n):
# ...

# %%
start_time = time.time()
pbil = PBIL(objective=Objective(),population_size=600, games_for_iter=5, opponent_strategy_list= np.array([(MoveStrategy(depth=2).minimax, 150)]), n=1, learning_rate=0.55, mutation_probability=0.02, mutation_constant=0.2)
pbil.run_n_times()
pbil.save()
pbil.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [-3 -1  0  4 10] [5 8 7 0 7] [8]
# n: 0, iter: 1
# [10  9 -6  3  3] [ 5 -3  7 -7 -7] [-2]
# n: 0, iter: 2
# [ 4 -5  0 -6  1] [ 5  9 -2  9  7] [6]
# n: 0, iter: 3
# [ 4 -5  0 -6  1] [ 5  9 -2  9  7] [6]
# n: 0, iter: 4
# [ 4  9 -6  5  1] [ 9  9 -2  9  7] [6]
# n: 0, iter: 5
# [ 2  8 -6  0  7] [ 9 -3  2  9  7] [9]
# n: 0, iter: 6
# [4 9 0 5 7] [9 9 0 9 7] [9]
# n: 0, iter: 7
# [4 9 0 5 1] [9 9 0 9 7] [1]
# n: 0, iter: 8
# [-1  9  0 -6  1] [-6  9 -2  9  7] [1]
# n: 0, iter: 9
# [-1  9 -6 -6  7] [ 5 -1  4  9  5] [9]
# n: 0, iter: 10
# [-1  9 -6  5  7] [ 5  9 -2  9  7] [6]
# n: 0, iter: 11
# [ 4 -5 -6  5  7] [ 5  9 -2  9  7] [6]
# n: 0, iter: 12
# [4 9 0 5 7] [ 9 -1 -2  9  7] [6]
# n: 0, iter: 13
# [-1  9 -9  5  7] [ 5  9 -2  9  7] [6]
# n: 0, iter: 14
# [-1  9 -6  5  7] [ 5 -1 -1  9  7] [6]
# n: 0, iter: 15
# [-1 -5 -9  5  7] [ 5  9 -2  9  7] [6]
# n: 0, iter: 16
# ...

# %%
start_time = time.time()
pbil_random = PBIL(objective=Objective(),population_size=70, descendant_size=20, opponent_strategy=MoveStrategy.minimax, iters=50, n=1, learning_rate=0.22, mutation_probability=0.1, mutation_constant=0.15, depth=2)
pbil_random.run_n_times()
pbil_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [ 4 -3 10 -2 -3] [ 9 -3 -4 -5 -6] [-4]
# n: 0, iter: 1
# [ 5 -3 10 -2 -8] [ 6 -5 -4 -7  0] [-10]
# n: 0, iter: 2
# [-9 -3 -1 -7 -3] [ 8 -5 -9 -4 -6] [9]
# n: 0, iter: 3
# [ 5 -3  4 -7  1] [ 3  6 -9 -4 -8] [-4]
# n: 0, iter: 4
# [ 4 -3 -5 -7 -2] [ 6 -5 -9  0  6] [6]
# n: 0, iter: 5
# [ -9  -3  -1  -7 -10] [ 6 -5 -9 -4 -6] [6]
# n: 0, iter: 6
# [-9 -3 -9 -7  1] [ 4 -5 -8  1  0] [6]
# n: 0, iter: 7
# [  6  -3   1   2 -10] [ 6 -3 -9  1 -8] [6]
# n: 0, iter: 8
# [  6  -3  -5  -2 -10] [ 6  6 -9  2  0] [6]
# n: 0, iter: 9
# [  6  -3  -1   3 -10] [ 6  6 -9  1  8] [9]
# n: 0, iter: 10
# [ -9  -3  -1  -8 -10] [ 4 -5 -9  1  8] [8]
# n: 0, iter: 11
# [  5   3   1  -8 -10] [ 4  6 -2  2  0] [8]
# n: 0, iter: 12
# [ -9  -3  -6  -8 -10] [-7  6 -9  2  6] [8]
# n: 0, iter: 13
# [  6  -3   4  -2 -10] [-7 -5 -2  2  8] [-6]
# n: 0, iter: 14
# [-9 -3  4 -5  2] [-1  6 -2  2 -8] [8]
# n: 0, iter: 15
# ...

# %%
start_time = time.time()
pbil_random = PBIL(objective=Objective(),population_size=200, descendant_size=20, opponent_strategy=MoveStrategy.minimax, iters=50, n=1, learning_rate=0.35, mutation_probability=0.05, mutation_constant=0.3, depth=2)
pbil_random.run_n_times()
pbil_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [ 1 -5 -2  6 -3] [ 0  4 -4  0 -7] [-9]
# n: 0, iter: 1
# [-3 -5 -2  6 -8] [ 7 -9  5  7 -9] [-9]
# n: 0, iter: 2
# [ 1  1 -2  6 -5] [ 7  4  5  7 10] [1]
# n: 0, iter: 3
# [-3 -9 -2  3 -8] [ 7 -9  5 -3  5] [-9]
# n: 0, iter: 4
# [-3 -9 -2  7 -5] [-3  4 -4 -3 -5] [-9]
# n: 0, iter: 5
# [ 1 -9 -2  3 -8] [ 8 -9  5 -3 10] [-9]
# n: 0, iter: 6
# [-5 10 -4 -4 -8] [ 8  4  5 -3 10] [1]
# n: 0, iter: 7
# [ 6 10  9 -4 -8] [-3  4  5 -3 -3] [-9]
# n: 0, iter: 8
# [ 6 10  9  3 -8] [ 7  4 -4 -3 -4] [-7]
# n: 0, iter: 9
# [ 6 10  9  3 -8] [ 7 -9 -4 -3 -9] [-9]
# n: 0, iter: 10
# [ 6 10  9  3 -8] [ 7 -9  5 -3 -4] [-9]
# n: 0, iter: 11
# [ 6 10  9  3 -8] [-5 -9 -4 -3 -9] [-9]
# n: 0, iter: 12
# [ 6 10  9  3 -8] [-5 -9 -4 -3 -9] [-7]
# n: 0, iter: 13
# [ 6 10  9 -4 -8] [-7 -9 -4 -3 -9] [-9]
# n: 0, iter: 14
# [ 6 10  9  3 -8] [ 7 -9 -4 -3 -4] [-9]
# n: 0, iter: 15
# ...

# %%
start_time = time.time()
pbil_random = PBIL(objective=Objective(),population_size=200, descendant_size=20, opponent_strategy=MoveStrategy.minimax, iters=50, n=1, learning_rate=0.5, mutation_probability=0.085, mutation_constant=0.4, depth=2)
pbil_random.run_n_times()
pbil_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [-1  8  6  4  1] [ -7 -10  10  -3  -4] [-7]
# n: 0, iter: 1
# [-1  8  6  4  1] [ -7 -10  10  -3  -4] [-7]
# n: 0, iter: 2
# [-1  8  6  4  1] [ -7 -10  10  -3  -4] [-2]
# n: 0, iter: 3
# [-5  8  6 -3  1] [ -7 -10  10  -3  -4] [-2]
# n: 0, iter: 4
# [-5  8  6  4  1] [-7  0 10 -3 -4] [-2]
# n: 0, iter: 5
# [-5  8  6  4  1] [-7  0 10 -3 -4] [-2]
# n: 0, iter: 6
# [-1  8  6  4  1] [-7  0 10 -3 -4] [-2]
# n: 0, iter: 7
# [-1  8 -7  4  1] [-7  0 10 -3 -4] [-2]
# n: 0, iter: 8
# [-1  8 -7  4  1] [-7  0 10 -3 -4] [-2]
# n: 0, iter: 9
# [-1  8 -7 -3  1] [-7  4 10 -3 -4] [-2]
# n: 0, iter: 10
# [-1  8 -7 -3  1] [-7  4 10 -3 -4] [-2]
# n: 0, iter: 11
# [-1  8 -7 -3 -3] [-7  4 10  1 -4] [-2]
# n: 0, iter: 12
# [-1  8 -7 -3  5] [-7  4 10  1  4] [-2]
# n: 0, iter: 13
# [-5  8 -7 -3 -4] [-7  4 10  1 -8] [-2]
# n: 0, iter: 14
# [-5  8 -7 -3 -4] [-7  4 10  1 -8] [-2]
# n: 0, iter: 15
# ...

# %%
pbil_random = PBIL(objective=Objective(),population_size=300, descendant_size=20, opponent_strategy=MoveStrategy.minimax, iters=100, n=1, learning_rate=0.55, mutation_probability=0.02, mutation_constant=0.2, depth=2)
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [ -4 -10   5  -4   2] [-4 -1  1 -5 -8] [6]
# n: 0, iter: 1
# [-4 -7  5 -4  2] [-1 -1  1 -5  7] [2]
# n: 0, iter: 2
# [ -4 -10   5  -4   2] [ 7 -1  1 -5 -8] [10]
# n: 0, iter: 3
# [-4 -7 -2 -4  2] [ 7 -1 -4 -5 -8] [5]
# n: 0, iter: 4
# [ -4 -10   5  -4   2] [-1 -1 -4 -5 -8] [-9]
# n: 0, iter: 5
# [ -4 -10   5  -4   2] [-1 -1 -4 -5 -8] [2]
# n: 0, iter: 6
# [ -4 -10   5  -4   2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 7
# [-4 -7  5 -4  2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 8
# [ -4 -10   5  -4   2] [-1 -1 -4 -5 -8] [2]
# n: 0, iter: 9
# [-4 -7  5 -4  2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 10
# [ -4 -10   5  -4   2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 11
# [ -5 -10   5  -4   2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 12
# [ -5 -10   5  -4   2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 13
# [ -5 -10   5  -4   2] [-1 -1 -4 -5  7] [2]
# n: 0, iter: 14
# [ -5 -10   5  -4   2] [-1 -1 -4 -5  7] [2]
# ...

# %%
start_time = time.time()
pbil_random = PBIL(objective=Objective(),population_size=600, descendant_size=20, opponent_strategy=MoveStrategy.minimax, iters=250, n=1, learning_rate=0.55, mutation_probability=0.02, mutation_constant=0.2, depth=2)
pbil_random.run_n_times()
pbil_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [-7  6 -4  3  7] [ -2   3   8   3 -10] [5]
# n: 0, iter: 1
# [ -5 -10  -2  -3   7] [-10  -9   2   7   9] [-3]
# n: 0, iter: 2
# [ 7 -7  9 -3 -9] [-2  3 -7  7 -2] [6]
# n: 0, iter: 3
# [-10  -6  -4 -10  10] [-9 -9  9 10 -2] [-6]
# n: 0, iter: 4
# [  2  -5   9 -10   8] [ 0 -1 -9 -2 -2] [10]
# n: 0, iter: 5
# [  2  -5 -10   1  -9] [-2  6  2  7 -3] [-7]
# n: 0, iter: 6
# [ 2  7 -8 -6 10] [  0 -10  -9  -8   6] [6]
# n: 0, iter: 7
# [ 2  7  9 -6  8] [ -9 -10  -9   6  -3] [8]
# n: 0, iter: 8
# [ 2 -6 -8 -3 -9] [-9  4  9 -8  6] [-7]
# n: 0, iter: 9
# [  0  -5 -10   1  -9] [ 1  3 -9 -6 -3] [4]
# n: 0, iter: 10
# [-6 -6 -8 -3  8] [-9  4 -3  7  6] [5]
# n: 0, iter: 11
# [10 -5  9 -3 -9] [-2  3 -9 -2 -2] [8]
# n: 0, iter: 12
# [ 0 -5  9 -3 10] [-2 -1  1 -2  6] [4]
# n: 0, iter: 13
# [-6 -5  4  0 10] [0 4 1 7 6] [8]
# n: 0, iter: 14
# [ 2 -5  9 -3 10] [-9 -1 -3  6 -2] [8]
# n: 0, iter: 15
# ...

# %%
start_time = time.time()
umdac_random = PBILc(objective=Objective(), population_size=50, descendant_size=10, opponent_strategy=MoveStrategy.minimax, learning_rate=0.55, mutation_probability=0.02, disturbance_constant=0.90, disturbance_probability=0.1, iters=20, n=2, depth=2)
umdac_random.run_n_times()
umdac_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# n: 0, iter: 1
# n: 0, iter: 2
# n: 0, iter: 3
# n: 0, iter: 4
# n: 0, iter: 5
# n: 0, iter: 6
# n: 0, iter: 7
# n: 0, iter: 8
# n: 0, iter: 9
# n: 0, iter: 10
# n: 0, iter: 11
# n: 0, iter: 12
# n: 0, iter: 13
# n: 0, iter: 14
# n: 0, iter: 15
# n: 0, iter: 16
# n: 0, iter: 17
# n: 0, iter: 18
# n: 0, iter: 19
# ---------------------------------------------------
# n: 1, iter: 0
# n: 1, iter: 1
# n: 1, iter: 2
# n: 1, iter: 3
# n: 1, iter: 4
# n: 1, iter: 5
# n: 1, iter: 6
# n: 1, iter: 7
# n: 1, iter: 8
# n: 1, iter: 9
# n: 1, iter: 10
# n: 1, iter: 11
# n: 1, iter: 12
# n: 1, iter: 13
# n: 1, iter: 14
# n: 1, iter: 15
# n: 1, iter: 16
# n: 1, iter: 17
# n: 1, iter: 18
# n: 1, iter: 19
# Time: 178.37329053878784

# %%
start_time = time.time()
pbil_random = PBIL(objective=Objective(),population_size=300, descendant_size=20, opponent_strategy=MoveStrategy.minimax, iters=150, n=1, learning_rate=0.4, mutation_probability=0.05, mutation_constant=0.2, depth=2)
pbil_random.run_n_times()
pbil_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# [ 6 -5 -7  2 10] [-5  5  3 -4 -8] [6]
# n: 0, iter: 1
# [ 1  8 -4  2  9] [ 1  7  8  7 -3] [3]
# n: 0, iter: 2
# [ -4  -3  -4   0 -10] [ -3  -3   6 -10  -3] [3]
# n: 0, iter: 3
# [-10  -5  -4   2   8] [ -6  -3 -10 -10   6] [10]
# n: 0, iter: 4
# [-2 -4 -2  2  8] [ -6  -8  -4 -10  -8] [3]
# n: 0, iter: 5
# [-2 -4 -2  2  8] [ -6  -8  -4 -10  -8] [3]
# n: 0, iter: 6
# [ -4   4  -4   6 -10] [ -6  -3 -10   5   6] [3]
# n: 0, iter: 7
# [ -4  -4 -10   1   8] [ -6  -3 -10   5  -8] [-9]
# n: 0, iter: 8
# [-4 -3 -4  1  9] [ -6  -3 -10   2   6] [6]
# n: 0, iter: 9
# [ -4  -3  -2  -9 -10] [-3 -8 -7  2 -8] [-9]
# n: 0, iter: 10
# [-4  3 -5 10 -4] [-3 -3 -4 -5  6] [6]
# n: 0, iter: 11
# [ -4   6  -5   6 -10] [-3 -3 -4  2  6] [3]
# n: 0, iter: 12
# [ 5  2 -2 -9 -4] [-3 -8 -7  2  6] [6]
# n: 0, iter: 13
# [-4 -3 -5 -9 -4] [-3 -8  9  2 -8] [-4]
# n: 0, iter: 14
# ...

# %%
start_time = time.time()
pbil_random = PBIL(objective=Objective(),population_size=100, opponent_strategy=MoveStrategy.minimax, iters=50, n=1, learning_rate=0.75, mutation_probability=0.05, mutation_constant=0.2, depth=2)
pbil_random.run_n_times()
pbil_random.show()
end_time = time.time()
print(f'Time: {end_time - start_time}')
# Out:
# Size pawns, size kings:  7360 7315
# ---------------------------------------------------
# n: 0, iter: 0
# no. best pawns:  2
# no. worst pawns:  10
# [  1   0   5 -10  -6] [-5 -1 -2  7  0] [-9]
# n: 0, iter: 1
# no. best pawns:  2
# no. worst pawns:  9
# [-8 -7  2  3  1] [ 6 -7 -8  0 10] [6]
# n: 0, iter: 2
# no. best pawns:  2
# no. worst pawns:  9
# [-9 -4  3 10  9] [ 2  5 10  5 -9] [-2]
# n: 0, iter: 3
# no. best pawns:  2
# no. worst pawns:  9
# [10 -7 10  3 -2] [-7  0 -4 -3 -9] [4]
# n: 0, iter: 4
# no. best pawns:  3
# no. worst pawns:  9
# [-6 -9  9  3 -8] [-7 -3 -4 -3 10] [-2]
# n: 0, iter: 5
# no. best pawns:  3
# no. worst pawns:  9
# [ 10 -10   2   3  -8] [ 9  7 -5 -7 10] [-2]
# n: 0, iter: 6
# no. best pawns:  3
# no. worst pawns:  8
# [-5 -7  2 -1 -8] [-7 -8 -5 -7 10] [-2]
# n: 0, iter: 7
# no. best pawns:  3
# no. worst pawns:  8
# [-9 -9 10  3 -8] [-7  7 -5 -7 10] [-2]
# n: 0, iter: 8
# no. best pawns:  4
# no. worst pawns:  8
# [-6 -9  2  3 -8] [-7  7 -5 -7 10] [-2]
# ...
